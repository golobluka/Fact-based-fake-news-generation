# %%
import pandas as pd
from src.General_generate_topics_of_fact import generate_fake_news
import os

filename = "vaccination_synthetic_articles_2.csv"

current_file = os.path.abspath(",")
current_diretory = os.path.dirname(current_file)
data_directory = os.path.join(current_diretory, "data")
final_path = os.path.join(data_directory, "filtered-all-vaccination-recovery-news-data.csv")

df = pd.read_csv(final_path, nrows=100)
articles = list(df["body_text"])[:5]

results = generate_fake_news(articles, 1, 1, 1, print_comments=True, testing=True)
#Desplay final_results in table format

display(results)
final_results = results.dropna()
display(final_results)
final_results.to_csv(filename, index=False)
# Out:
# c:\Users\Lukag\OneDrive\Documents\github\Fact-based-fake-news-generation
# c:\Users\Lukag\OneDrive\Documents\github
# Imported Constants Successfully.
# [{'Name of fact': 'Number of hostages', 'Description of fact': 'The total number of people being held by terrorists in Gaza.', 'Common examples': '240'}, {'Name of fact': 'Status of release negotiations', 'Description of fact': 'Information about the progress and prospects of releasing the hostages.', 'Common examples': 'Ongoing, Uncertain, Possible'}, {'Name of fact': 'Humanitarian aid efforts', 'Description of fact': 'Efforts to increase the flow of aid into Gaza to alleviate suffering among the civilian population.', 'Common examples': 'Increase, Implement localized pauses, Discuss additional pauses'}]
# Imported Constants Successfully.
# Imported Constants Successfully.
# Imported Constants Successfully.
# c:\Users\Lukag\OneDrive\Documents\github\Fact-based-fake-news-generation
# ...

# %%
import pandas as pd
from src.General_generate_topics_of_fact import generate_fake_news_repeated_indices_added
import os

filename = "vaccination_synthetic_articles_2.csv"

current_file = os.path.abspath(",")
current_diretory = os.path.dirname(current_file)
data_directory = os.path.join(current_diretory, "data")
final_path = os.path.join(data_directory, "filtered-all-vaccination-recovery-news-data.csv")

df = pd.read_csv(final_path, nrows=100)
articles = list(df["body_text"])[:5]
articles_ids = [1,2,3,4,5]



results = generate_fake_news_repeated_indices_added(articles, 2, 2, 2, print_comments=True, articles_ids=articles_ids,testing=True)
#Desplay final_results in table format

display(results)
final_results = results.dropna()
display(final_results)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lukag\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 14
#      12 df = pd.read_csv(final_path, nrows=100)
# ...
